# %% [markdown]
# # Part 1: extracting text from online job postings

# %% [markdown]
# ## Data extraction and cleaning

# %%
import pandas as pd
import os

# %matplotlib inline

# %%
directory = r'C:\Manning\resume-job-posting-nlp-project\data\html_job_postings'
os.chdir(directory)

data = []
for file in os.listdir(directory):
    file_name = os.path.basename(file)
    with open(file, mode='r', encoding='utf-8') as f:
        file_content = f.read()
        data.append([file_name, file_content])

df = pd.DataFrame(data, columns=['file_name', 'html'])

# %%
df.head()
# Out:
#                      file_name  \
# 0  001b92395ed0fb62_fccid.html
# 1  00321a48d04fe754_fccid.html
# 2  0079c11b2611349f_fccid.html
# 3  007d9d7b5c09d820_fccid.html
# 4  0125eabc844281c9_fccid.html
#
#                                                 html
# 0  <html><head><title>Data Engineer - Columbus, G...
# 1  <html><head><title>Data Analyst - St. Louis, M...
# 2  <html><head><title>Data Scientist - Newark, CA...
# 3  <html><head><title>Patient Care Assistant / PC...
# 4  <html><head><title>Scientific Programmer - Ber...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                         file_name  \
# 0     001b92395ed0fb62_fccid.html
# 1     00321a48d04fe754_fccid.html
# 2     0079c11b2611349f_fccid.html
# 3     007d9d7b5c09d820_fccid.html
# 4     0125eabc844281c9_fccid.html
# ...                           ...
# 1332  fee42538d4a7bb9a_fccid.html
# 1333  fefb9642ac28b85e_fccid.html
# 1334  ff0eb6d0b4da2289_fccid.html
# 1335  ff81a90403a3f37e_fccid.html
# 1336                      _p.html
#
#                                                    html
# 0     <html><head><title>Data Engineer - Columbus, G...
# 1     <html><head><title>Data Analyst - St. Louis, M...
# 2     <html><head><title>Data Scientist - Newark, CA...
# 3     <html><head><title>Patient Care Assistant / PC...
# 4     <html><head><title>Scientific Programmer - Ber...
# ...                                                 ...
# 1332  <html><head><title>Data Scientist - Glen Mills...
# 1333  <html><head><title>Data Analyst (Part-Time) - ...
# 1334  <html><head><title>Manager - Business Developm...
# 1335  <html><head><title>Natural Language Processing...
# 1336  <html><head><title>Director, Data Scientist, N...
#
# [1337 rows x 2 columns]>

# %%
df['duplicate'] = df.duplicated(subset='html', keep=False)

# %%
df.loc[df['duplicate'] == True]
# Out:
#                         file_name  \
# 10    0203a50423c1dff3_fccid.html
# 190   22ec5abff932581e_fccid.html
# 726   85a24b62479fad81_fccid.html
# 774   905ed810a40c9bb1_fccid.html
# 781   92b3776c33af25d7_fccid.html
# 789   94ae6fa4bc90abbf_fccid.html
# 859   a1d949a71fe0ab4b_fccid.html
# 860    a1d949a71fe0ab4b_from.html
# 894   a74cbd9c94a1536e_fccid.html
# 939   af7a8336b016a707_fccid.html
# 1086  cea97a9548587fa6_fccid.html
# 1200  e48fd1b2b39aaa18_fccid.html
# 1212  e5d505bd4b37baba_fccid.html
# 1272  f3da022757d22cfd_fccid.html
# 1291  f7073e5203088d8f_fccid.html
# 1336                      _p.html
#
#                                                    html  duplicate
# 10    <html><head><title>Deep Learning Engineer - We...       True
# 190   <html><head><title>Machine Learning Engineer -...       True
# 726   <html><head><title>Staff Data Scientist - NLP ...       True
# 774   <html><head><title>Machine Learning Engineer -...       True
# 781   <html><head><title>Page Not Found - Indeed Mob...       True
# 789   <html><head><title>Personal Care Assistant - Y...       True
# 859   <html><head><title>Principal Data Scientist - ...       True
# 860   <html><head><title>Principal Data Scientist - ...       True
# 894   <html><head><title>Data Scientist - Customer A...       True
# 939   <html><head><title>Deep Learning Engineer - We...       True
# 1086  <html><head><title>Personal Care Assistant - Y...       True
# 1200  <html><head><title>Page Not Found - Indeed Mob...       True
# 1212  <html><head><title>Director, Data Scientist, N...       True
# 1272  <html><head><title>Data Scientist - Customer A...       True
# 1291  <html><head><title>Staff Data Scientist - NLP ...       True
# 1336  <html><head><title>Director, Data Scientist, N...       True

# %%
df.drop_duplicates(subset='html', keep='first', inplace=True)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                         file_name  \
# 0     001b92395ed0fb62_fccid.html
# 1     00321a48d04fe754_fccid.html
# 2     0079c11b2611349f_fccid.html
# 3     007d9d7b5c09d820_fccid.html
# 4     0125eabc844281c9_fccid.html
# ...                           ...
# 1331  fe385aa11883568f_fccid.html
# 1332  fee42538d4a7bb9a_fccid.html
# 1333  fefb9642ac28b85e_fccid.html
# 1334  ff0eb6d0b4da2289_fccid.html
# 1335  ff81a90403a3f37e_fccid.html
#
#                                                    html  duplicate
# 0     <html><head><title>Data Engineer - Columbus, G...      False
# 1     <html><head><title>Data Analyst - St. Louis, M...      False
# 2     <html><head><title>Data Scientist - Newark, CA...      False
# 3     <html><head><title>Patient Care Assistant / PC...      False
# 4     <html><head><title>Scientific Programmer - Ber...      False
# ...                                                 ...        ...
# 1331  <html><head><title>Research Statistician - HEO...      False
# 1332  <html><head><title>Data Scientist - Glen Mills...      False
# 1333  <html><head><title>Data Analyst (Part-Time) - ...      False
# 1334  <html><head><title>Manager - Business Developm...      False
# 1335  <html><head><title>Natural Language Processing...      False
#
# [1329 rows x 3 columns]>

# %%
df.drop(columns='duplicate', inplace=True)

# %%
df.head()
# Out:
#                      file_name  \
# 0  001b92395ed0fb62_fccid.html
# 1  00321a48d04fe754_fccid.html
# 2  0079c11b2611349f_fccid.html
# 3  007d9d7b5c09d820_fccid.html
# 4  0125eabc844281c9_fccid.html
#
#                                                 html
# 0  <html><head><title>Data Engineer - Columbus, G...
# 1  <html><head><title>Data Analyst - St. Louis, M...
# 2  <html><head><title>Data Scientist - Newark, CA...
# 3  <html><head><title>Patient Care Assistant / PC...
# 4  <html><head><title>Scientific Programmer - Ber...

# %% [markdown]
# ## Parse title, body, and bullet points

# %%
from bs4 import BeautifulSoup as bs

def parse_title(html):
    soup = bs(html, 'lxml')
    title = soup.find('title').text
    
    return title

def parse_body(html):
    soup = bs(html, 'lxml')
    body = soup.body.text
    
    return body

def parse_bullets(html):
    soup = bs(html, 'lxml')
    bullets = [bullet.text for bullet in soup.body.find_all('li')]
    
    return bullets

# %%
df2 = pd.DataFrame()
df['title'] = df['html'].apply(parse_title)
df['body'] = df['html'].apply(parse_body)
df['bullets'] = df['html'].apply(parse_bullets, result_type=)

# %%
df.head()
# Out:
#                      file_name  \
# 0  001b92395ed0fb62_fccid.html
# 1  00321a48d04fe754_fccid.html
# 2  0079c11b2611349f_fccid.html
# 3  007d9d7b5c09d820_fccid.html
# 4  0125eabc844281c9_fccid.html
#
#                                                 html  \
# 0  <html><head><title>Data Engineer - Columbus, G...
# 1  <html><head><title>Data Analyst - St. Louis, M...
# 2  <html><head><title>Data Scientist - Newark, CA...
# 3  <html><head><title>Patient Care Assistant / PC...
# 4  <html><head><title>Scientific Programmer - Ber...
#
#                                                title  \
# 0                 Data Engineer - Columbus, GA 31909
# 1                       Data Analyst - St. Louis, MO
# 2                        Data Scientist - Newark, CA
# 3  Patient Care Assistant / PCA - Med/Surg (Fayet...
# 4               Scientific Programmer - Berkeley, CA
#
#                                                 body  \
# 0  Data Engineer - Columbus, GA 31909\nCelebratin...
# 1  Data Analyst - St. Louis, MO\nDuties\nSummary\...
# 2  Data Scientist - Newark, CA\nData Scientist\n\...
# 3  Patient Care Assistant / PCA - Med/Surg (Fayet...
# 4  Scientific Programmer - Berkeley, CA\nCaribou ...
#
#                                              bullets
# 0  [Bachelor’s or Master’s degree in statistics, ...
# 1  [Job family (Series)\n1501 General Mathematics...
# 2  [ Design, develop, document and maintain machi...
# 3  [Provides all personal care services in accord...
# 4  [Demonstrated proficiency with Python, JavaScr...

# %% [markdown]
# ## Save dataframe to disk

# %%
df.to_csv(r'..\job_postings.csv')
